# %%
#내풀이 
def solution(s):
    limit_num = len(s)//2
    answer = ''
    que = ''
    min_num = 1000000000
    for i in range(1,limit_num+1):
        for j in range(0,len(s),i):
            if s[j:j+i] ==s[j+i:j+2*i]:
                que+=s[j:j+i]
            else:
                if que:
                    que+=s[j:j+i]
                    # print(f'que={que}, i={i}')
                    nums = len(que)//i
                    answer += str(nums)
                    answer += que[:i]
                    que = ''
                else:
                    answer += s[j:j+i]
        length = len(answer)
        # if length == 0:
        #     continue
        # else:
        if length <= min_num:
                # print(answer)
            min_num = length
        answer =''
    if min_num == 1000000000:
        return len(s)
    return min_num





#다른 사람풀이

def compress(text, tok_len):
    words = [text[i:i+tok_len] for i in range(0, len(text), tok_len)]
    res = []
    cur_word = words[0]
    cur_cnt = 1
    for a, b in zip(words, words[1:] + ['']):  # 마지막 종결일때 역시 비교해주기 위해서 "" 추가해줌
                                                # 앞뒤 비교를 zip으로 사용해도 가능함
#         k = words[1:] + ['']
#         print(f'words = {words}, res = {k}')
#         print(f'a = {a}, b = {b}')
        if a == b:
            cur_cnt += 1
        else:
            res.append([cur_word, cur_cnt])
            cur_word = b
            cur_cnt = 1
    return sum(len(word) + (len(str(cnt)) if cnt > 1 else 0) for word, cnt in res)

def solution(text):
    return min(compress(text, tok_len) for tok_len in list(range(1, int(len(text)/2) + 1)) + [len(text)])

a = [
    "aabbaccc",
    "ababcdcdababcdcd",
    "abcabcdede",
    "abcabcabcabcdededededede",
    "xababcdcdababcdcd",

    'aaaaaa',
]

for x in a:
    print(solution(x))
# Out:
# words = ['a', 'a', 'b', 'b', 'a', 'c', 'c', 'c'], res = ['a', 'b', 'b', 'a', 'c', 'c', 'c', '']
# a = a, b = a
# words = ['a', 'a', 'b', 'b', 'a', 'c', 'c', 'c'], res = ['a', 'b', 'b', 'a', 'c', 'c', 'c', '']
# a = a, b = b
# words = ['a', 'a', 'b', 'b', 'a', 'c', 'c', 'c'], res = ['a', 'b', 'b', 'a', 'c', 'c', 'c', '']
# a = b, b = b
# words = ['a', 'a', 'b', 'b', 'a', 'c', 'c', 'c'], res = ['a', 'b', 'b', 'a', 'c', 'c', 'c', '']
# a = b, b = a
# words = ['a', 'a', 'b', 'b', 'a', 'c', 'c', 'c'], res = ['a', 'b', 'b', 'a', 'c', 'c', 'c', '']
# a = a, b = c
# words = ['a', 'a', 'b', 'b', 'a', 'c', 'c', 'c'], res = ['a', 'b', 'b', 'a', 'c', 'c', 'c', '']
# a = c, b = c
# words = ['a', 'a', 'b', 'b', 'a', 'c', 'c', 'c'], res = ['a', 'b', 'b', 'a', 'c', 'c', 'c', '']
# a = c, b = c
# words = ['a', 'a', 'b', 'b', 'a', 'c', 'c', 'c'], res = ['a', 'b', 'b', 'a', 'c', 'c', 'c', '']
# a = c, b =
# words = ['aa', 'bb', 'ac', 'cc'], res = ['bb', 'ac', 'cc', '']
# a = aa, b = bb
# words = ['aa', 'bb', 'ac', 'cc'], res = ['bb', 'ac', 'cc', '']
# a = bb, b = ac
# words = ['aa', 'bb', 'ac', 'cc'], res = ['bb', 'ac', 'cc', '']
# a = ac, b = cc
# words = ['aa', 'bb', 'ac', 'cc'], res = ['bb', 'ac', 'cc', '']
# a = cc, b =
# words = ['aab', 'bac', 'cc'], res = ['bac', 'cc', '']
# a = aab, b = bac
# words = ['aab', 'bac', 'cc'], res = ['bac', 'cc', '']
# a = bac, b = cc
# words = ['aab', 'bac', 'cc'], res = ['bac', 'cc', '']
# a = cc, b =
# words = ['aabb', 'accc'], res = ['accc', '']
# a = aabb, b = accc
# words = ['aabb', 'accc'], res = ['accc', '']
# a = accc, b =
# words = ['aabbaccc'], res = ['']
# a = aabbaccc, b =
# 7
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = a, b = b
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = b, b = a
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = a, b = b
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = b, b = c
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = c, b = d
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = d, b = c
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = c, b = d
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = d, b = a
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = a, b = b
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = b, b = a
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = a, b = b
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = b, b = c
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = c, b = d
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = d, b = c
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = c, b = d
# words = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = d, b =
# words = ['ab', 'ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd'], res = ['ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd', '']
# a = ab, b = ab
# words = ['ab', 'ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd'], res = ['ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd', '']
# a = ab, b = cd
# words = ['ab', 'ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd'], res = ['ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd', '']
# a = cd, b = cd
# words = ['ab', 'ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd'], res = ['ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd', '']
# a = cd, b = ab
# words = ['ab', 'ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd'], res = ['ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd', '']
# a = ab, b = ab
# words = ['ab', 'ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd'], res = ['ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd', '']
# a = ab, b = cd
# words = ['ab', 'ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd'], res = ['ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd', '']
# a = cd, b = cd
# words = ['ab', 'ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd'], res = ['ab', 'cd', 'cd', 'ab', 'ab', 'cd', 'cd', '']
# a = cd, b =
# words = ['aba', 'bcd', 'cda', 'bab', 'cdc', 'd'], res = ['bcd', 'cda', 'bab', 'cdc', 'd', '']
# a = aba, b = bcd
# words = ['aba', 'bcd', 'cda', 'bab', 'cdc', 'd'], res = ['bcd', 'cda', 'bab', 'cdc', 'd', '']
# a = bcd, b = cda
# words = ['aba', 'bcd', 'cda', 'bab', 'cdc', 'd'], res = ['bcd', 'cda', 'bab', 'cdc', 'd', '']
# a = cda, b = bab
# words = ['aba', 'bcd', 'cda', 'bab', 'cdc', 'd'], res = ['bcd', 'cda', 'bab', 'cdc', 'd', '']
# a = bab, b = cdc
# words = ['aba', 'bcd', 'cda', 'bab', 'cdc', 'd'], res = ['bcd', 'cda', 'bab', 'cdc', 'd', '']
# a = cdc, b = d
# words = ['aba', 'bcd', 'cda', 'bab', 'cdc', 'd'], res = ['bcd', 'cda', 'bab', 'cdc', 'd', '']
# a = d, b =
# words = ['abab', 'cdcd', 'abab', 'cdcd'], res = ['cdcd', 'abab', 'cdcd', '']
# a = abab, b = cdcd
# words = ['abab', 'cdcd', 'abab', 'cdcd'], res = ['cdcd', 'abab', 'cdcd', '']
# a = cdcd, b = abab
# words = ['abab', 'cdcd', 'abab', 'cdcd'], res = ['cdcd', 'abab', 'cdcd', '']
# a = abab, b = cdcd
# words = ['abab', 'cdcd', 'abab', 'cdcd'], res = ['cdcd', 'abab', 'cdcd', '']
# a = cdcd, b =
# words = ['ababc', 'dcdab', 'abcdc', 'd'], res = ['dcdab', 'abcdc', 'd', '']
# a = ababc, b = dcdab
# words = ['ababc', 'dcdab', 'abcdc', 'd'], res = ['dcdab', 'abcdc', 'd', '']
# a = dcdab, b = abcdc
# words = ['ababc', 'dcdab', 'abcdc', 'd'], res = ['dcdab', 'abcdc', 'd', '']
# a = abcdc, b = d
# words = ['ababc', 'dcdab', 'abcdc', 'd'], res = ['dcdab', 'abcdc', 'd', '']
# a = d, b =
# words = ['ababcd', 'cdabab', 'cdcd'], res = ['cdabab', 'cdcd', '']
# a = ababcd, b = cdabab
# words = ['ababcd', 'cdabab', 'cdcd'], res = ['cdabab', 'cdcd', '']
# a = cdabab, b = cdcd
# words = ['ababcd', 'cdabab', 'cdcd'], res = ['cdabab', 'cdcd', '']
# a = cdcd, b =
# words = ['ababcdc', 'dababcd', 'cd'], res = ['dababcd', 'cd', '']
# a = ababcdc, b = dababcd
# words = ['ababcdc', 'dababcd', 'cd'], res = ['dababcd', 'cd', '']
# a = dababcd, b = cd
# words = ['ababcdc', 'dababcd', 'cd'], res = ['dababcd', 'cd', '']
# a = cd, b =
# words = ['ababcdcd', 'ababcdcd'], res = ['ababcdcd', '']
# a = ababcdcd, b = ababcdcd
# words = ['ababcdcd', 'ababcdcd'], res = ['ababcdcd', '']
# a = ababcdcd, b =
# words = ['ababcdcdababcdcd'], res = ['']
# a = ababcdcdababcdcd, b =
# 9
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = a, b = b
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = b, b = c
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = c, b = a
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = a, b = b
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = b, b = c
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = c, b = d
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = d, b = e
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = e, b = d
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = d, b = e
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', '']
# a = e, b =
# words = ['ab', 'ca', 'bc', 'de', 'de'], res = ['ca', 'bc', 'de', 'de', '']
# a = ab, b = ca
# words = ['ab', 'ca', 'bc', 'de', 'de'], res = ['ca', 'bc', 'de', 'de', '']
# a = ca, b = bc
# words = ['ab', 'ca', 'bc', 'de', 'de'], res = ['ca', 'bc', 'de', 'de', '']
# a = bc, b = de
# words = ['ab', 'ca', 'bc', 'de', 'de'], res = ['ca', 'bc', 'de', 'de', '']
# a = de, b = de
# words = ['ab', 'ca', 'bc', 'de', 'de'], res = ['ca', 'bc', 'de', 'de', '']
# a = de, b =
# words = ['abc', 'abc', 'ded', 'e'], res = ['abc', 'ded', 'e', '']
# a = abc, b = abc
# words = ['abc', 'abc', 'ded', 'e'], res = ['abc', 'ded', 'e', '']
# a = abc, b = ded
# words = ['abc', 'abc', 'ded', 'e'], res = ['abc', 'ded', 'e', '']
# a = ded, b = e
# words = ['abc', 'abc', 'ded', 'e'], res = ['abc', 'ded', 'e', '']
# a = e, b =
# words = ['abca', 'bcde', 'de'], res = ['bcde', 'de', '']
# a = abca, b = bcde
# words = ['abca', 'bcde', 'de'], res = ['bcde', 'de', '']
# a = bcde, b = de
# words = ['abca', 'bcde', 'de'], res = ['bcde', 'de', '']
# a = de, b =
# words = ['abcab', 'cdede'], res = ['cdede', '']
# a = abcab, b = cdede
# words = ['abcab', 'cdede'], res = ['cdede', '']
# a = cdede, b =
# words = ['abcabcdede'], res = ['']
# a = abcabcdede, b =
# 8
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = a, b = b
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = b, b = c
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = c, b = a
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = a, b = b
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = b, b = c
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = c, b = a
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = a, b = b
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = b, b = c
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = c, b = a
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = a, b = b
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = b, b = c
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = c, b = d
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = d, b = e
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = e, b = d
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = d, b = e
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = e, b = d
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = d, b = e
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = e, b = d
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = d, b = e
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = e, b = d
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = d, b = e
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = e, b = d
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = d, b = e
# words = ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e'], res = ['b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', 'd', 'e', '']
# a = e, b =
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = ab, b = ca
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = ca, b = bc
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = bc, b = ab
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = ab, b = ca
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = ca, b = bc
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = bc, b = de
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = de, b = de
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = de, b = de
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = de, b = de
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = de, b = de
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = de, b = de
# words = ['ab', 'ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de'], res = ['ca', 'bc', 'ab', 'ca', 'bc', 'de', 'de', 'de', 'de', 'de', 'de', '']
# a = de, b =
# words = ['abc', 'abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede'], res = ['abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede', '']
# a = abc, b = abc
# words = ['abc', 'abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede'], res = ['abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede', '']
# a = abc, b = abc
# words = ['abc', 'abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede'], res = ['abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede', '']
# a = abc, b = abc
# words = ['abc', 'abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede'], res = ['abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede', '']
# a = abc, b = ded
# words = ['abc', 'abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede'], res = ['abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede', '']
# a = ded, b = ede
# words = ['abc', 'abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede'], res = ['abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede', '']
# a = ede, b = ded
# words = ['abc', 'abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede'], res = ['abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede', '']
# a = ded, b = ede
# words = ['abc', 'abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede'], res = ['abc', 'abc', 'abc', 'ded', 'ede', 'ded', 'ede', '']
# a = ede, b =
# words = ['abca', 'bcab', 'cabc', 'dede', 'dede', 'dede'], res = ['bcab', 'cabc', 'dede', 'dede', 'dede', '']
# a = abca, b = bcab
# words = ['abca', 'bcab', 'cabc', 'dede', 'dede', 'dede'], res = ['bcab', 'cabc', 'dede', 'dede', 'dede', '']
# a = bcab, b = cabc
# words = ['abca', 'bcab', 'cabc', 'dede', 'dede', 'dede'], res = ['bcab', 'cabc', 'dede', 'dede', 'dede', '']
# a = cabc, b = dede
# words = ['abca', 'bcab', 'cabc', 'dede', 'dede', 'dede'], res = ['bcab', 'cabc', 'dede', 'dede', 'dede', '']
# a = dede, b = dede
# words = ['abca', 'bcab', 'cabc', 'dede', 'dede', 'dede'], res = ['bcab', 'cabc', 'dede', 'dede', 'dede', '']
# a = dede, b = dede
# words = ['abca', 'bcab', 'cabc', 'dede', 'dede', 'dede'], res = ['bcab', 'cabc', 'dede', 'dede', 'dede', '']
# a = dede, b =
# words = ['abcab', 'cabca', 'bcded', 'edede', 'dede'], res = ['cabca', 'bcded', 'edede', 'dede', '']
# a = abcab, b = cabca
# words = ['abcab', 'cabca', 'bcded', 'edede', 'dede'], res = ['cabca', 'bcded', 'edede', 'dede', '']
# a = cabca, b = bcded
# words = ['abcab', 'cabca', 'bcded', 'edede', 'dede'], res = ['cabca', 'bcded', 'edede', 'dede', '']
# a = bcded, b = edede
# words = ['abcab', 'cabca', 'bcded', 'edede', 'dede'], res = ['cabca', 'bcded', 'edede', 'dede', '']
# a = edede, b = dede
# words = ['abcab', 'cabca', 'bcded', 'edede', 'dede'], res = ['cabca', 'bcded', 'edede', 'dede', '']
# a = dede, b =
# words = ['abcabc', 'abcabc', 'dedede', 'dedede'], res = ['abcabc', 'dedede', 'dedede', '']
# a = abcabc, b = abcabc
# words = ['abcabc', 'abcabc', 'dedede', 'dedede'], res = ['abcabc', 'dedede', 'dedede', '']
# a = abcabc, b = dedede
# words = ['abcabc', 'abcabc', 'dedede', 'dedede'], res = ['abcabc', 'dedede', 'dedede', '']
# a = dedede, b = dedede
# words = ['abcabc', 'abcabc', 'dedede', 'dedede'], res = ['abcabc', 'dedede', 'dedede', '']
# a = dedede, b =
# words = ['abcabca', 'bcabcde', 'dededed', 'ede'], res = ['bcabcde', 'dededed', 'ede', '']
# a = abcabca, b = bcabcde
# words = ['abcabca', 'bcabcde', 'dededed', 'ede'], res = ['bcabcde', 'dededed', 'ede', '']
# a = bcabcde, b = dededed
# words = ['abcabca', 'bcabcde', 'dededed', 'ede'], res = ['bcabcde', 'dededed', 'ede', '']
# a = dededed, b = ede
# words = ['abcabca', 'bcabcde', 'dededed', 'ede'], res = ['bcabcde', 'dededed', 'ede', '']
# a = ede, b =
# words = ['abcabcab', 'cabcdede', 'dededede'], res = ['cabcdede', 'dededede', '']
# a = abcabcab, b = cabcdede
# words = ['abcabcab', 'cabcdede', 'dededede'], res = ['cabcdede', 'dededede', '']
# a = cabcdede, b = dededede
# words = ['abcabcab', 'cabcdede', 'dededede'], res = ['cabcdede', 'dededede', '']
# a = dededede, b =
# words = ['abcabcabc', 'abcdedede', 'dedede'], res = ['abcdedede', 'dedede', '']
# a = abcabcabc, b = abcdedede
# words = ['abcabcabc', 'abcdedede', 'dedede'], res = ['abcdedede', 'dedede', '']
# a = abcdedede, b = dedede
# words = ['abcabcabc', 'abcdedede', 'dedede'], res = ['abcdedede', 'dedede', '']
# a = dedede, b =
# words = ['abcabcabca', 'bcdededede', 'dede'], res = ['bcdededede', 'dede', '']
# a = abcabcabca, b = bcdededede
# words = ['abcabcabca', 'bcdededede', 'dede'], res = ['bcdededede', 'dede', '']
# a = bcdededede, b = dede
# words = ['abcabcabca', 'bcdededede', 'dede'], res = ['bcdededede', 'dede', '']
# a = dede, b =
# words = ['abcabcabcab', 'cdedededede', 'de'], res = ['cdedededede', 'de', '']
# a = abcabcabcab, b = cdedededede
# words = ['abcabcabcab', 'cdedededede', 'de'], res = ['cdedededede', 'de', '']
# a = cdedededede, b = de
# words = ['abcabcabcab', 'cdedededede', 'de'], res = ['cdedededede', 'de', '']
# a = de, b =
# words = ['abcabcabcabc', 'dededededede'], res = ['dededededede', '']
# a = abcabcabcabc, b = dededededede
# words = ['abcabcabcabc', 'dededededede'], res = ['dededededede', '']
# a = dededededede, b =
# words = ['abcabcabcabcdededededede'], res = ['']
# a = abcabcabcabcdededededede, b =
# 14
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = x, b = a
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = a, b = b
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = b, b = a
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = a, b = b
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = b, b = c
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = c, b = d
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = d, b = c
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = c, b = d
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = d, b = a
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = a, b = b
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = b, b = a
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = a, b = b
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = b, b = c
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = c, b = d
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = d, b = c
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = c, b = d
# words = ['x', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd'], res = ['a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', 'a', 'b', 'a', 'b', 'c', 'd', 'c', 'd', '']
# a = d, b =
# words = ['xa', 'ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd'], res = ['ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd', '']
# a = xa, b = ba
# words = ['xa', 'ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd'], res = ['ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd', '']
# a = ba, b = bc
# words = ['xa', 'ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd'], res = ['ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd', '']
# a = bc, b = dc
# words = ['xa', 'ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd'], res = ['ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd', '']
# a = dc, b = da
# words = ['xa', 'ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd'], res = ['ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd', '']
# a = da, b = ba
# words = ['xa', 'ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd'], res = ['ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd', '']
# a = ba, b = bc
# words = ['xa', 'ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd'], res = ['ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd', '']
# a = bc, b = dc
# words = ['xa', 'ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd'], res = ['ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd', '']
# a = dc, b = d
# words = ['xa', 'ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd'], res = ['ba', 'bc', 'dc', 'da', 'ba', 'bc', 'dc', 'd', '']
# a = d, b =
# words = ['xab', 'abc', 'dcd', 'aba', 'bcd', 'cd'], res = ['abc', 'dcd', 'aba', 'bcd', 'cd', '']
# a = xab, b = abc
# words = ['xab', 'abc', 'dcd', 'aba', 'bcd', 'cd'], res = ['abc', 'dcd', 'aba', 'bcd', 'cd', '']
# a = abc, b = dcd
# words = ['xab', 'abc', 'dcd', 'aba', 'bcd', 'cd'], res = ['abc', 'dcd', 'aba', 'bcd', 'cd', '']
# a = dcd, b = aba
# words = ['xab', 'abc', 'dcd', 'aba', 'bcd', 'cd'], res = ['abc', 'dcd', 'aba', 'bcd', 'cd', '']
# a = aba, b = bcd
# words = ['xab', 'abc', 'dcd', 'aba', 'bcd', 'cd'], res = ['abc', 'dcd', 'aba', 'bcd', 'cd', '']
# a = bcd, b = cd
# words = ['xab', 'abc', 'dcd', 'aba', 'bcd', 'cd'], res = ['abc', 'dcd', 'aba', 'bcd', 'cd', '']
# a = cd, b =
# words = ['xaba', 'bcdc', 'daba', 'bcdc', 'd'], res = ['bcdc', 'daba', 'bcdc', 'd', '']
# a = xaba, b = bcdc
# words = ['xaba', 'bcdc', 'daba', 'bcdc', 'd'], res = ['bcdc', 'daba', 'bcdc', 'd', '']
# a = bcdc, b = daba
# words = ['xaba', 'bcdc', 'daba', 'bcdc', 'd'], res = ['bcdc', 'daba', 'bcdc', 'd', '']
# a = daba, b = bcdc
# words = ['xaba', 'bcdc', 'daba', 'bcdc', 'd'], res = ['bcdc', 'daba', 'bcdc', 'd', '']
# a = bcdc, b = d
# words = ['xaba', 'bcdc', 'daba', 'bcdc', 'd'], res = ['bcdc', 'daba', 'bcdc', 'd', '']
# a = d, b =
# words = ['xabab', 'cdcda', 'babcd', 'cd'], res = ['cdcda', 'babcd', 'cd', '']
# a = xabab, b = cdcda
# words = ['xabab', 'cdcda', 'babcd', 'cd'], res = ['cdcda', 'babcd', 'cd', '']
# a = cdcda, b = babcd
# words = ['xabab', 'cdcda', 'babcd', 'cd'], res = ['cdcda', 'babcd', 'cd', '']
# a = babcd, b = cd
# words = ['xabab', 'cdcda', 'babcd', 'cd'], res = ['cdcda', 'babcd', 'cd', '']
# a = cd, b =
# words = ['xababc', 'dcdaba', 'bcdcd'], res = ['dcdaba', 'bcdcd', '']
# a = xababc, b = dcdaba
# words = ['xababc', 'dcdaba', 'bcdcd'], res = ['dcdaba', 'bcdcd', '']
# a = dcdaba, b = bcdcd
# words = ['xababc', 'dcdaba', 'bcdcd'], res = ['dcdaba', 'bcdcd', '']
# a = bcdcd, b =
# words = ['xababcd', 'cdababc', 'dcd'], res = ['cdababc', 'dcd', '']
# a = xababcd, b = cdababc
# words = ['xababcd', 'cdababc', 'dcd'], res = ['cdababc', 'dcd', '']
# a = cdababc, b = dcd
# words = ['xababcd', 'cdababc', 'dcd'], res = ['cdababc', 'dcd', '']
# a = dcd, b =
# words = ['xababcdc', 'dababcdc', 'd'], res = ['dababcdc', 'd', '']
# a = xababcdc, b = dababcdc
# words = ['xababcdc', 'dababcdc', 'd'], res = ['dababcdc', 'd', '']
# a = dababcdc, b = d
# words = ['xababcdc', 'dababcdc', 'd'], res = ['dababcdc', 'd', '']
# a = d, b =
# words = ['xababcdcdababcdcd'], res = ['']
# a = xababcdcdababcdcd, b =
# 17
# words = ['a', 'a', 'a', 'a', 'a', 'a'], res = ['a', 'a', 'a', 'a', 'a', '']
# a = a, b = a
# words = ['a', 'a', 'a', 'a', 'a', 'a'], res = ['a', 'a', 'a', 'a', 'a', '']
# a = a, b = a
# words = ['a', 'a', 'a', 'a', 'a', 'a'], res = ['a', 'a', 'a', 'a', 'a', '']
# a = a, b = a
# words = ['a', 'a', 'a', 'a', 'a', 'a'], res = ['a', 'a', 'a', 'a', 'a', '']
# a = a, b = a
# words = ['a', 'a', 'a', 'a', 'a', 'a'], res = ['a', 'a', 'a', 'a', 'a', '']
# a = a, b = a
# words = ['a', 'a', 'a', 'a', 'a', 'a'], res = ['a', 'a', 'a', 'a', 'a', '']
# a = a, b =
# words = ['aa', 'aa', 'aa'], res = ['aa', 'aa', '']
# a = aa, b = aa
# words = ['aa', 'aa', 'aa'], res = ['aa', 'aa', '']
# a = aa, b = aa
# words = ['aa', 'aa', 'aa'], res = ['aa', 'aa', '']
# a = aa, b =
# words = ['aaa', 'aaa'], res = ['aaa', '']
# a = aaa, b = aaa
# words = ['aaa', 'aaa'], res = ['aaa', '']
# a = aaa, b =
# words = ['aaaaaa'], res = ['']
# a = aaaaaa, b =
# 2
