# %% [markdown]
# <a href="https://colab.research.google.com/github/hoon2hooni/code_practice/blob/master/baekJoon%201018%20fill%20the%20chass%20board.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check(row, col, colors):
    cnt = 0
    print(row,col)
    for i in range(0+row,8+row,2):
        for j in range(0+col, 8+col, 2):
            if arr[i][j] !=colors[0]:
                #print(f'i={i},j={j}, colors[0]={colors[0]}')
                cnt += 1
        for j in range(1+col,8+col,2):
            if arr[i][j] != colors[1]:
                cnt += 1
                #print(f'i={i},j={j}, colors[0]={colors[0]}')
    for i in range(1+row,8+row,2):
        for j in range(1+col, 8+col, 2):
            if arr[i][j] !=colors[0]:
                #print(f'i={i},j={j}, colors[0]={colors[0]}')
                cnt += 1
        for j in range(0+col,8+col,2):
            if arr[i][j] != colors[1]:
                #print(f'i={i},j={j}, colors[0]={colors[0]}')
                cnt += 1

    print(cnt)
    return cnt


# r, c = map(int, input().split())
# arr = [list(input()) for i in range(r)]
c_list = [['B','W'],['W','B']]
min_cnt = 64
for i in range(0, r-8+1):
    for j in range(0, c-8+1):
        for l in c_list:
            print(l)
            print(n)
            n = check(i,j,l)
            if n < min_cnt:
              min_cnt = n
# print(arr[1][1] == c_list[1][0]) 
# print(c_list[1][0])      
print(min_cnt)
# Out:
# ['B', 'W']
# 47
# 0 0
# 32
# ['W', 'B']
# 32
# 0 0
# 32
# ['B', 'W']
# 32
# 0 1
# 28
# ['W', 'B']
# 28
# 0 1
# 36
# ['B', 'W']
# 36
# 0 2
# 40
# ['W', 'B']
# 40
# 0 2
# 24
# ['B', 'W']
# 24
# 0 3
# 20
# ['W', 'B']
# 20
# 0 3
# 44
# ['B', 'W']
# 44
# 0 4
# 48
# ['W', 'B']
# 48
# 0 4
# 16
# ['B', 'W']
# 16
# 0 5
# 12
# ['W', 'B']
# 12
# 0 5
# 52
# ['B', 'W']
# 52
# 1 0
# 32
# ['W', 'B']
# 32
# 1 0
# 32
# ['B', 'W']
# 32
# 1 1
# 35
# ['W', 'B']
# 35
# 1 1
# 29
# ['B', 'W']
# 29
# 1 2
# 25
# ['W', 'B']
# 25
# 1 2
# 39
# ['B', 'W']
# 39
# 1 3
# 41
# ['W', 'B']
# 41
# 1 3
# 23
# ['B', 'W']
# 23
# 1 4
# 19
# ['W', 'B']
# 19
# 1 4
# 45
# ['B', 'W']
# 45
# 1 5
# 47
# ['W', 'B']
# 47
# 1 5
# 17
# ['B', 'W']
# 17
# 2 0
# 32
# ['W', 'B']
# 32
# 2 0
# 32
# ['B', 'W']
# 32
# 2 1
# 29
# ['W', 'B']
# 29
# 2 1
# 35
# ['B', 'W']
# 35
# 2 2
# 38
# ['W', 'B']
# 38
# 2 2
# 26
# ['B', 'W']
# 26
# 2 3
# 23
# ['W', 'B']
# 23
# 2 3
# 41
# ['B', 'W']
# 41
# 2 4
# 44
# ['W', 'B']
# 44
# 2 4
# 20
# ['B', 'W']
# ...
