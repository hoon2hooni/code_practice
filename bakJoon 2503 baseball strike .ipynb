# %% [markdown]
# <a href="https://colab.research.google.com/github/hoon2hooni/code_practice/blob/master/bakJoon%202503%20baseball%20strike%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i =0
while i*(i+1) < 2000:
    i+=1
print(i)
# Out:
# 45

# %%
arr = [i*(i+1)/2 for i in range(1,45)]

# %%
for i in arr:
    for j in arr:
        for k in arr:
            if i + j + k == n:
# Out:
# 990.0

# %%
def check(n):
    for i in arr:
        for j in arr:
            for k in arr:
                if i + j + k == n:
                    print(i,j,k)
                    return 1
    
    else:
        return 0

ans = [check(i) for i in [20, 10, 1000]]
# Out:
# 1.0 3.0 6.0
# 3.0 136.0 861.0
# [0, 1, 1]

# %%
def check(n):
    for i in arr:
        for j in arr:
            for k in arr:
                if i + j + k == n:
                    return 1
    else:
        return 0

n = int(input())
nums = []
for i in range(n):
    nums.append(int(input()))
i =0
while i*(i+1) < 2000:
    i+=1
arr = [w*(w+1)//2 for w in range(1,i)]
ans =[check(y) for y in nums]
for n_ in ans:
    print(n_)
# Out:
# 3
# 10
# 20
# 1000
# 1
# 0
# 1

# %%
arr = [str(i) for i in range(100,999) if (str(i)[0] != str(i)[1]) and (str(i)[1] != str(i)[2]) and (str(i)[2] != str(i)[0])]

# %%
q_arr = ['123','1','1']

# %%
def strike(input_num, num, n):
    cnt = 0
    n = int(n)
    for i,j in zip(input_num, num):
        if i == j:
            cnt += 1
    if cnt == n:
        return True
    else:
        return False
    
def ball(input_num, num, n):
    cnt = 0
    n = int(n)
    for i in input_num:
        if i in num:
            cnt += 1
    if cnt == n:
        return True
    else:
        return False

# %%
# Out:
# ['123', '1', '1']

# %%
n = int(input())
q_arr = []
for i in range(n):
    q_arr.append(input().split())
# Out:
# 4
# 123 1 1
# 356 1 0
# 327 2 0
# 489 0 1

# %%
q_arr
# Out:
# [['123', '1', '1'], ['356', '1', '0'], ['327', '2', '0'], ['489', '0', '1']]

# %%
arr
# Out:
# ['102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '120',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '130',
#  '132',
#  '134',
#  '135',
#  '136',
#  '137',
#  '138',
#  '139',
#  '140',
#  '142',
#  '143',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '150',
#  '152',
#  '153',
#  '154',
#  '156',
#  '157',
#  '158',
#  '159',
#  '160',
#  '162',
#  '163',
#  '164',
#  '165',
#  '167',
#  '168',
#  '169',
#  '170',
#  '172',
#  '173',
#  '174',
#  '175',
#  '176',
#  '178',
#  '179',
#  '180',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '187',
#  '189',
#  '190',
#  '192',
#  '193',
#  '194',
#  '195',
#  '196',
#  '197',
#  '198',
#  '201',
#  '203',
#  '204',
#  '205',
#  '206',
#  '207',
#  '208',
#  '209',
#  '210',
#  '213',
#  '214',
#  '215',
#  '216',
#  '217',
#  '218',
#  '219',
#  '230',
#  '231',
#  '234',
#  '235',
#  '236',
#  '237',
#  '238',
#  '239',
#  '240',
#  '241',
#  '243',
#  '245',
# ...

# %%
arr
# Out:
# ['102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '120',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '130',
#  '132',
#  '134',
#  '135',
#  '136',
#  '137',
#  '138',
#  '139',
#  '140',
#  '142',
#  '143',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '150',
#  '152',
#  '153',
#  '154',
#  '156',
#  '157',
#  '158',
#  '159',
#  '160',
#  '162',
#  '163',
#  '164',
#  '165',
#  '167',
#  '168',
#  '169',
#  '170',
#  '172',
#  '173',
#  '174',
#  '175',
#  '176',
#  '178',
#  '179',
#  '180',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '187',
#  '189',
#  '190',
#  '192',
#  '193',
#  '194',
#  '195',
#  '196',
#  '197',
#  '198',
#  '201',
#  '203',
#  '204',
#  '205',
#  '206',
#  '207',
#  '208',
#  '209',
#  '210',
#  '213',
#  '214',
#  '215',
#  '216',
#  '217',
#  '218',
#  '219',
#  '230',
#  '231',
#  '234',
#  '235',
#  '236',
#  '237',
#  '238',
#  '239',
#  '240',
#  '241',
#  '243',
#  '245',
# ...

# %%
arr = [str(i) for i in range(100,999) if (str(i)[0] != str(i)[1]) and (str(i)[1] != str(i)[2]) and (str(i)[2] != str(i)[0])]

# %%
for n_ in range(n):
    arr = [i for i in arr if (ball(i, q_arr[n_][0],int(q_arr[n_][2])+int(q_arr[n_][1])))\
           and (strike(i, q_arr[n_][0] ,q_arr[n_][1]))]
    print(arr)
# Out:
# ['102', '130', '134', '135', '136', '137', '138', '139', '142', '152', '162', '172', '182', '192', '203', '243', '253', '263', '273', '283', '293', '320', '324', '325', '326', '327', '328', '329', '413', '421', '513', '521', '613', '621', '713', '721', '813', '821', '913', '921']
# ['152', '320', '324', '327', '328', '329']
# ['320', '324', '328', '329']
# ['324', '328']

# %%
ball('324','123',2)
# Out:
# True

# %%
arr = [str(i) for i in range(100,999) if (str(i)[0] != str(i)[1]) and (str(i)[1] != str(i)[2]) and (str(i)[2] != str(i)[0])]

# %%
[i for i in arr if (ball(i,q_arr[0][0],q_arr[0][1]))\
           and (strike(i, q_arr[0][0] ,q_arr[0][2]))]
# Out:
# ['104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '140',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '150',
#  '154',
#  '156',
#  '157',
#  '158',
#  '159',
#  '160',
#  '164',
#  '165',
#  '167',
#  '168',
#  '169',
#  '170',
#  '174',
#  '175',
#  '176',
#  '178',
#  '179',
#  '180',
#  '184',
#  '185',
#  '186',
#  '187',
#  '189',
#  '190',
#  '194',
#  '195',
#  '196',
#  '197',
#  '198',
#  '403',
#  '420',
#  '425',
#  '426',
#  '427',
#  '428',
#  '429',
#  '453',
#  '463',
#  '473',
#  '483',
#  '493',
#  '503',
#  '520',
#  '524',
#  '526',
#  '527',
#  '528',
#  '529',
#  '543',
#  '563',
#  '573',
#  '583',
#  '593',
#  '603',
#  '620',
#  '624',
#  '625',
#  '627',
#  '628',
#  '629',
#  '643',
#  '653',
#  '673',
#  '683',
#  '693',
#  '703',
#  '720',
#  '724',
#  '725',
#  '726',
#  '728',
#  '729',
#  '743',
#  '753',
#  '763',
#  '783',
#  '793',
#  '803',
#  '820',
#  '824',
#  '825',
#  '826',
#  '827',
#  '829',
#  '843',
#  '853',
#  '863',
# ...

# %%
'123'.startswith('1')
# Out:
# True

# %%
def strike(input_num, num, n):
    cnt = 0
    n = int(n)
    for i,j in zip(input_num, num):
        if i == j:
            cnt += 1
    if cnt == n:
        return True
    else:
        return False
    
def ball(input_num, num, n):
    cnt = 0
    n = int(n)
    for i in input_num:
        if i in num:
            cnt += 1
    if cnt == n:
        return True
    else:
        return False
    
arr = [str(i) for i in range(100,999) if (str(i)[0] != str(i)[1]) and (str(i)[1] != str(i)[2]) and (str(i)[2] != str(i)[0])]
arr = [i for i in arr if '0' not in i] 

n = int(input())
q_arr = []
for i in range(n):
    q_arr.append(input().split())
for n_ in range(n):
    arr = [i for i in arr if (ball(i, q_arr[n_][0],int(q_arr[n_][2])+int(q_arr[n_][1])))\
           and (strike(i, q_arr[n_][0] ,q_arr[n_][1]))]
print(len(arr))
# Out:
# 4
# 123 1 1
# 356 1 0
# 327 2 0
# 489 0 1
# 2

# %%
arr = [str(i) for i in range(100,999) if (str(i)[0] != str(i)[1]) and (str(i)[1] != str(i)[2]) and (str(i)[2] != str(i)[0])]
arr = [i for i in arr if '0' not in i]

# %%
print(arr)
# Out:
# ['123', '124', '125', '126', '127', '128', '129', '132', '134', '135', '136', '137', '138', '139', '142', '143', '145', '146', '147', '148', '149', '152', '153', '154', '156', '157', '158', '159', '162', '163', '164', '165', '167', '168', '169', '172', '173', '174', '175', '176', '178', '179', '182', '183', '184', '185', '186', '187', '189', '192', '193', '194', '195', '196', '197', '198', '213', '214', '215', '216', '217', '218', '219', '231', '234', '235', '236', '237', '238', '239', '241', '243', '245', '246', '247', '248', '249', '251', '253', '254', '256', '257', '258', '259', '261', '263', '264', '265', '267', '268', '269', '271', '273', '274', '275', '276', '278', '279', '281', '283', '284', '285', '286', '287', '289', '291', '293', '294', '295', '296', '297', '298', '312', '314', '315', '316', '317', '318', '319', '321', '324', '325', '326', '327', '328', '329', '341', '342', '345', '346', '347', '348', '349', '351', '352', '354', '356', '357', '358', '359', '361', '362', '36
# ...
